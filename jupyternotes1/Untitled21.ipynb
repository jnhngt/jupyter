# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import jieba
from collections import Counter
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %%
with open("yy.txt", "r", encoding="utf-8") as f:
    text = f.read()

text_clean = re.sub(r'[^\u4e00-\u9fa5]', ' ', text)
words = jieba.lcut(text_clean)

stopwords = ['和', '的', '是', '在', '以', '等', '为', '了', '与', '及', '对', '中', '上', '下', '或', '也', '都']
filtered_words = [word for word in words if word not in stopwords and len(word) > 1]
word_counts = Counter(filtered_words)

wc = WordCloud(
    background_color="white",
    width=1200,
    height=800,
    max_words=20,
    font_path="simhei.ttf",
    contour_width=2,
    contour_color="black"
)

wc.generate_from_frequencies(word_counts)

plt.figure(figsize=(12, 8), dpi=300)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")

plt.title("2025年政府工作报告核心词汇词云图（张宇洋）",fontsize=16, fontweight='bold', color="#36454F")
plt.text(0.5, 0.05, "2025年政府工作报告核心词汇分布",ha='center', va='center', transform=plt.gca().transAxes,fontsize=12, color="#333333")
plt.subplots_adjust(left=0.05, right=0.95, top=0.9, bottom=0.1)

plt.savefig("government_report_wordcloud_106.png", dpi=300, bbox_inches='tight')
plt.show()
