# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_excel("5-1.xlsx")

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
sns.boxplot(y=df["技术实现成绩"])
# Out:
# <Axes: ylabel='技术实现成绩'>

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
sns.boxplot(x=df["编程基础等级"],y=df["工程规范成绩"])
# Out:
# <Axes: xlabel='编程基础等级', ylabel='工程规范成绩'>

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
sns.boxplot(x=df["编程基础等级"],y=df["项目开发耗时"])
# Out:
# <Axes: xlabel='编程基础等级', ylabel='项目开发耗时'>

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
sns.boxplot(x=df["年级"],y=df["项目开发耗时"])
# Out:
# <Axes: xlabel='年级', ylabel='项目开发耗时'>
